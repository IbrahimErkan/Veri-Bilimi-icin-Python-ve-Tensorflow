# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyDizisi1 = np.linspace(0,10,20)

# %%
numpyDizisi1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyDizisi2 = numpyDizisi1 ** 2

# %%
numpyDizisi2
# Out:
# array([  0.        ,   0.27700831,   1.10803324,   2.49307479,
#          4.43213296,   6.92520776,   9.97229917,  13.5734072 ,
#         17.72853186,  22.43767313,  27.70083102,  33.51800554,
#         39.88919668,  46.81440443,  54.29362881,  62.32686981,
#         70.91412742,  80.05540166,  89.75069252, 100.        ])

# %%
(benimFigur, benimEksen) = pyt.subplots()

# %%
(benimFigur, benimEksen) = pyt.subplots()
benimEksen.plot(numpyDizisi1, numpyDizisi2, color="#40E0D0", alpha=0.3)
benimEksen.plot(numpyDizisi2,numpyDizisi1, color="#D68910")

# %%
(yeniFigur, yeniEksen) = plt.subplots()
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 2, color="blue", linewidth=1.0)
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 3, color="green", linewidth=1.0)

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 4, color = "#C96F23", linestyle = "-.")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 5, color = "#C96F23", linestyle = ":")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 6, color = "#C96F23", linestyle = "--")

yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 7, color = "#000000", linestyle = "--", marker = "o",markersize="8", markerfacecolor="red")
yeniEksen.plot(numpyDizisi1, numpyDizisi1 + 8, color = "#000000", linestyle = "--", marker = "+",markersize = "4")

# %% [markdown]
# # scatter

# %%
plt.scatter(numpyDizisi1,numpyDizisi2)

# %% [markdown]
# # histogram

# %%
yeniDizi = np.random.randint(0,100,50)

# %%
yeniDizi
# Out:
# array([11, 83,  8, 28,  5, 67, 95,  1, 64, 96, 99, 31, 44, 50, 24, 76, 59,
#        89, 43, 92,  5, 81, 45, 52, 21, 47, 73, 15, 57, 37, 24, 27, 84, 60,
#        33, 32, 89, 28, 16, 30, 82, 35,  6, 13, 82, 83, 50, 32, 58, 59])

# %%
plt.hist(yeniDizi)
# Out:
# (array([5., 4., 7., 6., 4., 7., 3., 2., 8., 4.]),
#  array([ 1. , 10.8, 20.6, 30.4, 40.2, 50. , 59.8, 69.6, 79.4, 89.2, 99. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# # boxplot

# %%
plt.boxplot(yeniDizi*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x28b2e0683d0>,
#   <matplotlib.lines.Line2D at 0x28b2e068730>],
#  'caps': [<matplotlib.lines.Line2D at 0x28b2e068a90>,
#   <matplotlib.lines.Line2D at 0x28b2e068df0>],
#  'boxes': [<matplotlib.lines.Line2D at 0x28b2e068070>],
#  'medians': [<matplotlib.lines.Line2D at 0x28b2e0751c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x28b2e075520>],
#  'means': []}
